# %% [markdown]
# <h4 align="center" style="height:1123px;font-family: 'Times New Roman'"><b>
#
#     LAPORAN PRAKTIKUM
#
#     ALGORITMA & PEMOGRAMAN
#
#     “CONDITIONAL PADA PYTHON”
#
#     Disusun Oleh :
#
#     Sabiril Rauf
#
#     2611532023
#
#     Dosen Pengampu:
#
#     Wahyudi.DR.. S.T.M.T
#
#     Asisten Praktikum:
#
#     Rifky Yuliandra
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
#     FAKULTAS TEKNOLOGI INFORMASI
#
#     DEPARTEMEN INFORMATIKA
#
#     UNIVERSITAS ANDALAS
#
#     2026
#
# </b></h4>
# </div>

# %% [markdown]
# ---
# <div style="height:1123px;font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# <h2 align="center">KATA PENGANTAR</h2>
# Puji syukur kehadirat Tuhan Yang Maha Esa karena atas rahmat dan karunia-Nya laporan praktikum yang berjudul “Conditional pada Python” ini dapat diselesaikan dengan baik. Laporan ini disusun untuk memenuhi salah satu tugas praktikum serta membantu memahami penggunaan percabangan dalam bahasa pemrograman Python.
#
# Dalam praktikum ini, penulis mempelajari konsep conditional pada Python, seperti penggunaan `if`, `elif`, dan `else` dalam membuat suatu program. Conditional digunakan untuk menentukan tindakan berdasarkan kondisi tertentu sehingga program dapat menjalankan perintah yang berbeda sesuai dengan keadaan yang diberikan. Dengan adanya praktikum ini, diharapkan penulis dapat memahami konsep percabangan dan menerapkannya dalam pembuatan program sederhana.
#
# Penulis menyadari bahwa laporan ini masih memiliki kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan agar laporan berikutnya dapat menjadi lebih baik. Semoga laporan ini dapat memberikan manfaat bagi penulis maupun pembaca dalam memahami dasar-dasar conditional pada Python.
#
#
#
# <div align="right" style="margin-left:-30px;">
# Padang, 2026
# <br>
# <br>
# <br>
# <br>
# <br>
# Sabiril Rauf
# <br>
# 2611532023
# </div>
# </div>

# %% [markdown]
# ---
# <div style="height:1123px;font-family: 'Times New Roman', Times, serif;font-size: 18px;">
# <h1 align="center">BAB I<br>PENDAHULUAN</h1>
#
# ## 1.1 Latar Belakang
# Dalam pemrograman, sebuah program tidak selalu menjalankan perintah yang sama. Terkadang program perlu menentukan tindakan berdasarkan kondisi atau keadaan tertentu. Oleh karena itu, dibutuhkan struktur percabangan yang memungkinkan program memilih perintah sesuai dengan kondisi yang diberikan. Salah satu bentuk percabangan tersebut adalah conditional.
#
# Python menyediakan beberapa pernyataan conditional, seperti `if`, `elif`, dan `else`. Struktur tersebut dapat digunakan untuk membuat program yang mampu mengambil keputusan berdasarkan hasil suatu kondisi. Pemahaman mengenai conditional menjadi salah satu dasar penting dalam pemrograman karena banyak program membutuhkan proses pengambilan keputusan.
#
# Melalui praktikum ini, mahasiswa mempelajari penggunaan conditional pada Python serta penerapannya dalam program sederhana. Dengan memahami konsep tersebut, mahasiswa diharapkan mampu membuat program yang dapat memberikan keluaran berbeda berdasarkan kondisi yang telah ditentukan.
#
# ## 1.2 Tujuan
# 1. Memahami konsep conditional pada bahasa pemrograman Python.
# 2. Mengetahui fungsi penggunaan `if`, `elif`, dan `else`.
# 3. Mampu membuat percabangan berdasarkan kondisi tertentu.
# 4. Mampu menerapkan conditional dalam pembuatan program sederhana.
# 5. Memahami penggunaan operator perbandingan dan logika dalam conditional.
#
# ## 1.3 Manfaat
# Praktikum ini membantu mahasiswa memahami konsep percabangan pada Python dan cara penggunaannya dalam program. Selain itu, praktikum ini dapat meningkatkan kemampuan dalam membuat program yang mampu mengambil keputusan berdasarkan kondisi tertentu.
# </div>

# %% [markdown]
# ---
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
# <h1 align="center">BAB II<br>PEMBAHASAN</h1>
#
# ## 2.1 Dasar Teori
# Conditional merupakan struktur dalam Python yang digunakan untuk menjalankan perintah berdasarkan kondisi tertentu. Dengan conditional, program dapat menentukan apakah suatu perintah akan dijalankan atau tidak berdasarkan hasil evaluasi kondisi.
#
# 1. Pernyataan if
# Pernyataan if digunakan untuk menjalankan suatu perintah apabila kondisi yang diberikan bernilai benar (True).
# umur = 18
# 2. Pernyataan if-else
# Pernyataan if-else digunakan ketika terdapat dua kemungkinan kondisi. Jika kondisi pada if bernilai benar, maka perintah pada if dijalankan. Jika salah, program menjalankan perintah pada else.
# 3. Pernyataan if-elif-else
# if-elif-else digunakan ketika terdapat lebih dari dua kondisi yang perlu diperiksa. Python akan memeriksa kondisi secara berurutan hingga menemukan kondisi yang bernilai benar.
#
# ## 2.2 Kode Program
#
# ### 2.2.1 Program if1_2611532023
# </div>

# %%
# Buat file dengan nama if1_nim.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

ipk_2023 = float(input("Input IPK Anda = "))

if ipk_2023 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK",str(ipk_2023))

print("Program Selesai")
# Out:
# Anda Lulus Sangat Memuaskan dengan IPK 4.0
# Program Selesai

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Program dimulai dengan meminta pengguna memasukkan nilai IPK melalui fungsi input().
# 2. Nilai IPK yang dimasukkan diubah menjadi tipe data float agar dapat digunakan sebagai nilai numerik dalam perhitungan dan perbandingan.
# 3. Nilai tersebut disimpan ke dalam variabel ipk_2023.
# 4. Program memeriksa kondisi menggunakan pernyataan if, yaitu apakah nilai ipk_2023 lebih besar dari 2.75.
# 5. Jika kondisi tersebut benar, program menampilkan pesan “Anda Lulus Sangat Memuaskan dengan IPK” beserta nilai IPK yang dimasukkan.
# 6. Jika kondisi tersebut salah, program tidak menjalankan perintah di dalam if dan langsung melanjutkan ke perintah berikutnya.
# 7. Program menampilkan pesan “Program Selesai”.
#
#
# ### 2.2.2 Program if2_2611532023
# </div>

# %%
# Buat file dengan nama if2_nim.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

ipk_2023 = float(input("Input IPK Anda = "))

if ipk_2023 > 2.75:
    print("Anda Lulus Sangat Memuaskan dengan IPK",str(ipk_2023))
else:
    print("Anda Tidak Lulus")
print("Program Selesai")
# Out:
# Anda Tidak Lulus
# Program Selesai

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Program dimulai dengan meminta pengguna memasukkan nilai IPK menggunakan fungsi `input()`.
# 2. Nilai IPK yang dimasukkan diubah menjadi tipe data `float` agar dapat digunakan dalam proses perbandingan.
# 3. Nilai tersebut disimpan ke dalam variabel `ipk_2023`.
# 4. Program memeriksa kondisi `if`, yaitu apakah nilai `ipk_2023` lebih besar dari `2.75`.
# 5. Jika kondisi bernilai benar, program menampilkan pesan **“Anda Lulus Sangat Memuaskan dengan IPK”** beserta nilai IPK yang dimasukkan.
# 6. Jika kondisi bernilai salah, program menjalankan bagian `else` dan menampilkan pesan **“Anda Tidak Lulus”**.
# 7. Setelah proses percabangan selesai, program menampilkan pesan **“Program Selesai”**.
#
# ### 2.2.3 Program multi_if1_2611532023
# </div>

# %%
# Buat file dengan nama multi_if1_nim.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

umur_2023 = int(input("Input Umur Anda = "))
sim_2023 = input("Apakah Anda Sudah Punya SIM (y/t): ")[0]

if umur_2023 >= 17 and sim_2023 == "y":
    print("Anda Sudah dewasa dan boleh bawa motor")

if umur_2023 >= 17 and sim_2023 != "y":
    print("Anda Sudah dewasa tetapi tidak boleh bawa motor")

if umur_2023 < 17 and sim_2023 != "y":
    print("Anda Belum Cukup Umur bawa motor")

if umur_2023 < 17 and sim_2023 == "y":
    print("Anda Belum Cukup Umur punya SIM")
# Out:
# Anda Sudah dewasa dan boleh bawa motor

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Program dimulai dengan meminta pengguna memasukkan umur menggunakan fungsi `input()`.
# 2. Nilai umur diubah menjadi tipe data `int` dan disimpan dalam variabel `umur_2023`.
# 3. Program meminta pengguna memasukkan apakah sudah memiliki SIM dengan pilihan `y` atau `t`. Karakter pertama dari input diambil menggunakan `[0]` dan disimpan dalam variabel `sim_2023`.
# 4. Program memeriksa kondisi pertama, yaitu `umur_2023 >= 17` dan `sim_2023 == "y"`. Jika kedua kondisi benar, program menampilkan bahwa pengguna sudah dewasa dan boleh membawa motor.
# 5. Program memeriksa kondisi kedua, yaitu umur sudah 17 tahun atau lebih tetapi `sim_2023` bukan `"y"`. Jika benar, program menampilkan bahwa pengguna sudah dewasa tetapi tidak boleh membawa motor.
# 6. Program memeriksa kondisi ketiga, yaitu umur kurang dari 17 tahun dan `sim_2023` bukan `"y"`. Jika benar, program menampilkan bahwa pengguna belum cukup umur untuk membawa motor.
# 7. Program memeriksa kondisi keempat, yaitu umur kurang dari 17 tahun tetapi `sim_2023` sama dengan `"y"`. Jika benar, program menampilkan bahwa pengguna belum cukup umur untuk memiliki SIM.
# 8. Setelah seluruh kondisi diperiksa, program selesai.
#
# ### 2.2.4 Program multi_if2_2611532023
# </div>

# %%
# Buat file dengan nama multi_if2_nim.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()
# Program Menghitung Diskon Belanja

# Input dan user
total_belanja_2023 = float(input("Input Total Belanja (Rp): "))

# Input status member (mengecek apakah user mengetik 'y atau 't')
input_member_2023 = input("Apakah Anda Member (y/t): ").strip().lower()
is_member_2023 = input_member_2023 in ["y", "t"]

# Input satus kode promo (mengecek apakah user mengetik 'y atau 't')
input_promo_2023 = input("Apakah kode promo valid? (y/t): ").strip().lower()
kode_promo_valid_2023 = input_promo_2023 in ["y", "t"]

total_diskon_persen_2023 = 0

# Multi-if terpisah: Setiap kondisi diperiksa secara independen
# Diskon bisa ditumpuk (akumulasi) jika memenuhi beberapa syarat sekaligus

if total_belanja_2023 > 1000000:
    total_diskon_persen_2023 += 10  # Diskon total besar

if is_member_2023:
    total_diskon_persen_2023 += 5  # Diskon member

if kode_promo_valid_2023:
    total_diskon_persen_2023 += 15  # Diskon voucher

# Menghitung nominal diskon dan total bayar
nominal_diskon_2023 = total_belanja_2023 * (total_diskon_persen_2023 / 100)
total_bayar_2023 = total_belanja_2023 - nominal_diskon_2023

# Output hasil
print("\n--- Rincian Pembayaran ---")
print(f"Total Diskon  : {total_diskon_persen_2023} (Rp {nominal_diskon_2023:.0f})")
print(f"Total Bayar   : Rp {total_bayar_2023:.0f}")

print(f"Total diskon yang Anda dapatkan: {total_diskon_persen_2023}%")
# Output: Total diskon yang Anda dapatkan: 30% jika belanja > 1 juta, member, dan kode promo valid
# Out:
# --- Rincian Pembayaran ---
# Total Diskon  : 20 (Rp 200000)
# Total Bayar   : Rp 800000
# Total diskon yang Anda dapatkan: 20%

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Program dimulai dengan meminta pengguna memasukkan **total belanja** dalam rupiah menggunakan fungsi `input()`.
# 2. Nilai total belanja diubah menjadi tipe data `float` dan disimpan dalam variabel `total_belanja_2023`.
# 3. Program meminta pengguna memasukkan status member dengan pilihan `y` atau `t`. Input kemudian diubah menjadi huruf kecil menggunakan `.lower()` dan spasi yang tidak diperlukan dihapus menggunakan `.strip()`.
# 4. Program memeriksa apakah input member berupa `"y"` atau `"t"` menggunakan operator `in`. Hasil pemeriksaan disimpan dalam variabel `is_member_2023`.
# 5. Program meminta pengguna memasukkan status kode promo dengan pilihan `y` atau `t`. Input diproses dengan cara yang sama dan hasilnya disimpan dalam variabel `kode_promo_valid_2023`.
# 6. Variabel `total_diskon_persen_2023` diberikan nilai awal `0` sebagai tempat untuk menyimpan jumlah persentase diskon.
# 7. Program memeriksa kondisi pertama. Jika total belanja lebih dari **Rp1.000.000**, program menambahkan diskon sebesar **10%**.
# 8. Program memeriksa kondisi kedua. Jika pengguna merupakan member, program menambahkan diskon sebesar **5%**.
# 9. Program memeriksa kondisi ketiga. Jika kode promo dianggap valid, program menambahkan diskon sebesar **15%**.
# 10. Karena menggunakan beberapa `if` yang terpisah, setiap kondisi diperiksa secara independen. Jika beberapa kondisi terpenuhi, persentase diskon akan **diakumulasikan**.
# 11. Program menghitung nominal diskon dengan mengalikan total belanja dengan persentase diskon yang telah diperoleh.
# 12. Program menghitung total pembayaran dengan mengurangi total belanja dengan nominal diskon.
# 13. Program menampilkan rincian pembayaran berupa total persentase diskon, nominal diskon dalam rupiah, dan total yang harus dibayar.
# 14. Program menampilkan kembali jumlah diskon yang diperoleh dalam bentuk persentase.
#
# ### 2.2.5 Program if_elif_else1_2611532023
# </div>

# %%
# Buat file dengan nama if_elif_else1_nim.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()

umur_2023 = int(input("Input Umur Anda = "))
sim_2023 = input("Apakah Anda Sudah Punya SIM (y/t): ")[0]

if umur_2023 >= 17 and sim_2023 == "y":
    print("Anda Sudah dewasa dan boleh bawa motor")
elif umur_2023 >= 17 and sim_2023 != "y":
    print("Anda Sudah dewasa tetapi tidak boleh bawa motor")
elif umur_2023 < 17 and sim_2023 == "y":
    print("Anda Belum Cukup Umur punya SIM")
else:
    print("Anda Belum Cukup Umur dan tidak boleh bawa motor")
print("Program Selesai")
# Out:
# Anda Sudah dewasa dan boleh bawa motor
# Program Selesai

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Program dimulai dengan meminta pengguna memasukkan umur menggunakan fungsi `input()`.
# 2. Nilai umur diubah menjadi tipe data `int` dan disimpan dalam variabel `umur_2023`.
# 3. Program meminta pengguna memasukkan status kepemilikan SIM dengan pilihan `y` atau `t`. Karakter pertama dari input diambil menggunakan `[0]` dan disimpan dalam variabel `sim_2023`.
# 4. Program memeriksa kondisi pertama, yaitu apakah umur pengguna **17 tahun atau lebih** dan memiliki SIM (`sim_2023 == "y"`). Jika kondisi benar, program menampilkan bahwa pengguna sudah dewasa dan boleh membawa motor.
# 5. Jika kondisi pertama salah, program memeriksa kondisi `elif` kedua, yaitu apakah umur pengguna **17 tahun atau lebih** tetapi tidak memiliki SIM. Jika benar, program menampilkan bahwa pengguna sudah dewasa tetapi tidak boleh membawa motor.
# 6. Jika kondisi kedua juga salah, program memeriksa kondisi `elif` ketiga, yaitu apakah umur pengguna **kurang dari 17 tahun** tetapi memiliki SIM. Jika benar, program menampilkan bahwa pengguna belum cukup umur untuk memiliki SIM.
# 7. Jika seluruh kondisi sebelumnya salah, program menjalankan bagian `else` dan menampilkan bahwa pengguna belum cukup umur dan tidak boleh membawa motor.
# 8. Setelah salah satu kondisi terpenuhi, program menampilkan pesan **"Program Selesai"**.
#
# ### 2.2.6 Program nilai_2611532023
# </div>

# %%
# Buat file dengan nama nilai_nim.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi nilai angka menjadi huruf

nilai_2023 = int(input("Input nilai angka: "))

if nilai_2023 >= 81:
    print("A")
elif nilai_2023 >= 70:
    print("B")
elif nilai_2023 >= 60:
    print("C")
elif nilai_2023 >= 50:
    print("D")
else:
    print("E")
# Out:
# B

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Program dimulai dengan meminta pengguna memasukkan nilai angka menggunakan fungsi `input()`.
# 2. Nilai yang dimasukkan diubah menjadi tipe data `int` dan disimpan dalam variabel `nilai_2023`.
# 3. Program memeriksa kondisi pertama, yaitu apakah nilai **lebih besar atau sama dengan 81**. Jika benar, program menampilkan nilai **A**.
# 4. Jika kondisi pertama salah, program memeriksa kondisi `elif` kedua, yaitu apakah nilai **lebih besar atau sama dengan 70**. Jika benar, program menampilkan nilai **B**.
# 5. Jika kondisi kedua salah, program memeriksa kondisi `elif` ketiga, yaitu apakah nilai **lebih besar atau sama dengan 60**. Jika benar, program menampilkan nilai **C**.
# 6. Jika kondisi ketiga salah, program memeriksa kondisi `elif` keempat, yaitu apakah nilai **lebih besar atau sama dengan 50**. Jika benar, program menampilkan nilai **D**.
# 7. Jika seluruh kondisi sebelumnya salah, program menjalankan bagian `else` dan menampilkan nilai **E**.
# 8. Setelah salah satu kondisi terpenuhi, program selesai.
#
# ### 2.2.7 Program match_case1_2611532023
# </div>

# %%
# Buat file dengan nama case1.py
# Buat program untuk kodisional if
# Nama variabel ditambah 4 digit terakhir contoh: ipk_1234
# Program ini menggunakan fungsi input()
# Program konversi angka menjadi nama bulan

bulan_2023 = int(input("Masukkan angka bulan (1 - 12): "))

match bulan_2023:
    case 1:
        print("Januari")
    case 2:
        print("Februari")
    case 3:
        print("Maret")
    case 4:
        print("April")
    case 5:
        print("Mei")
    case 6:
        print("Juni")
    case 7:
        print("Juli")
    case 8:
        print("Agustus")
    case 9:
        print("September")
    case 10:
        print("Oktober")
    case 11:
        print("November")
    case 12:
        print("Desember")
    case _:
        print("Angka tidak valid")
# Out:
# Mei

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# Penjelasan:
# 1. Program dimulai dengan meminta pengguna memasukkan angka bulan dari **1 sampai 12** menggunakan fungsi `input()`.
# 2. Nilai yang dimasukkan diubah menjadi tipe data `int` dan disimpan dalam variabel `bulan_2023`.
# 3. Program menggunakan struktur **`match-case`** untuk mencocokkan nilai `bulan_2023` dengan beberapa pilihan yang tersedia.
# 4. Jika nilai yang dimasukkan adalah **1**, program menampilkan **Januari**.
# 5. Jika nilai **2 sampai 12**, program menampilkan nama bulan yang sesuai, mulai dari Februari hingga Desember.
# 6. Jika angka yang dimasukkan tidak sesuai dengan angka **1 sampai 12**, program menjalankan `case _` dan menampilkan pesan **"Angka tidak valid"**.
# 7. Setelah nama bulan atau pesan kesalahan ditampilkan, program selesai.
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/soal_tugas.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>
#
# **Kode Jawaban :**
#
# a. Kode Program tugas3_2611532023
# </div>

# %%
print("=== SISTEM LOKET ALPRO ADVENTURE PARK ===")
nama_2023 = input("Masukkan Nama Pengunjung        : ")
umur_2023 = int(input("Input umur anda                 : "))

# .strip().lower() untuk menangani input string
sim_2023 = input("Apakah Anda Sudah Punya SIM C (y/t): ").strip().lower()

# Menu Paket Wahana
print("\nPilihan Paket Wahana (1-5):")
print("  1. Safari Rimba         (Rp 50,000)")
print("  2. Arung Jeram          (Rp 75,000)")
print("  3. Motor ATV Ekstrim    (Rp 120,000)")
print("  4. Roller Coaster Kilat (Rp 100,000)")
print("  5. All-Access VIP       (Rp 220,000)")

paket_2023 = input("Masukkan nomor paket (1-5)      : ").strip()
jumlah_tiket_2023 = int(input("Masukkan jumlah tiket           : "))

# Pilar 1: IF Tunggal untuk Validasi Kelogisan Tiket
if jumlah_tiket_2023 <= 0:
    print("[PERINGATAN] Kuota tiket tidak valid!")
    exit()

is_member_2023 = input("Apakah Anda member? (y/t)       : ").strip().lower()
kode_promo_valid_2023 = input("Apakah kode promo valid? (y/t)  : ").strip().lower()

# Inisialisasi variabel pendukung
harga_satuan_2023 = 0
status_akses_2023 = ""

# Pilar 2: MATCH - CASE untuk Pemilihan Wahana
match paket_2023:
    case "1":
        harga_satuan_2023 = 50000
    case "2":
        harga_satuan_2023 = 75000
    case "3":
        harga_satuan_2023 = 120000
    case "4":
        harga_satuan_2023 = 100000
    case "5":
        harga_satuan_2023 = 220000
    case _:
        print("Paket wahana tidak valid!")
        exit()

# Pilar 3: IF - ELIF - ELSE dan Operator Logika untuk Validasi Izin Kendali
print("\n--- KELAYAKAN PENGENDARA WAHANA ---")
if paket_2023 == "3":
    if umur_2023 >= 17 and sim_2023 == 'y':
        status_akses_2023 = "Anda sudah dewasa dan boleh mengendarai ATV sendiri."
    elif umur_2023 >= 17 and sim_2023 != 'y':
        status_akses_2023 = "Anda sudah dewasa tetapi tidak boleh bawa motor ATV (wajib didampingi instruktur)."
    elif umur_2023 < 17 and sim_2023 == 'y':
        status_akses_2023 = "Identitas tidak valid: Belum cukup umur memiliki SIM."
    else:
        status_akses_2023 = "Anda belum cukup umur dan tidak boleh bawa motor ATV."
else:
    if umur_2023 >= 10:
        status_akses_2023 = "Anda memenuhi syarat umur untuk menikmati wahana ini."
    else:
        status_akses_2023 = "Anda belum cukup umur untuk menikmati wahana ini."

print(f"Status Akses: {status_akses_2023}")

# Perhitungan Subtotal
subtotal_2023 = harga_satuan_2023 * jumlah_tiket_2023
total_diskon_persen_2023 = 0

# Pilar 4: MULTI-IF Terpisah untuk Akumulasi Diskon Bertingkat
if subtotal_2023 >= 200000:
    total_diskon_persen_2023 += 10

if is_member_2023 in ['y', 'ya']:
    total_diskon_persen_2023 += 5

if kode_promo_valid_2023 in ['y', 'ya']:
    total_diskon_persen_2023 += 15

if jumlah_tiket_2023 >= 5:
    total_diskon_persen_2023 += 5

# Perhitungan Nominal Diskon dan Total Bayar
nominal_diskon_2023 = subtotal_2023 * (total_diskon_persen_2023 / 100)
total_bayar_2023 = subtotal_2023 - nominal_diskon_2023

# Pilar 5: IF - ELSE untuk Evaluasi Kelulusan Audit & Bonus
catatan_layanan_2023 = ""
if total_bayar_2023 > 300000:
    catatan_layanan_2023 = "Selamat! Anda berhak mendapatkan Souvenir Gratis."
else:
    catatan_layanan_2023 = "Terima kasih telah berkunjung."

# OUTPUT RINCIAN PEMBAYARAN (Format Desimal f-string)
print("\n--- Rincian Pembayaran ---")
print(f"Subtotal Belanja : Rp {subtotal_2023:,.0f}")
print(f"Total Diskon     : {total_diskon_persen_2023}% (Rp {nominal_diskon_2023:,.0f})")
print(f"Total Bayar      : Rp {total_bayar_2023:,.0f}")
print(f"Catatan Layanan  : {catatan_layanan_2023}")
print("Program Selesai")
# Out:
# === SISTEM LOKET ALPRO ADVENTURE PARK ===
#
# Pilihan Paket Wahana (1-5):
#   1. Safari Rimba         (Rp 50,000)
#   2. Arung Jeram          (Rp 75,000)
#   3. Motor ATV Ekstrim    (Rp 120,000)
#   4. Roller Coaster Kilat (Rp 100,000)
#   5. All-Access VIP       (Rp 220,000)
#
# --- KELAYAKAN PENGENDARA WAHANA ---
# Status Akses: Anda memenuhi syarat umur untuk menikmati wahana ini.
#
# --- Rincian Pembayaran ---
# Subtotal Belanja : Rp 200,000
# Total Diskon     : 30% (Rp 60,000)
# Total Bayar      : Rp 140,000
# Catatan Layanan  : Terima kasih telah berkunjung.
# Program Selesai

# %% [markdown]
# <div style="font-family: 'Times New Roman', Times, serif;font-size: 18px;">
#
# **Penjelasan :**
# 1. Program dimulai dengan menampilkan judul **Sistem Loket Alpro Adventure Park**.
# 2. Program meminta pengguna memasukkan **nama pengunjung** dan menyimpannya pada variabel `nama_2023`.
# 3. Program meminta **umur pengunjung**, kemudian mengubah input menjadi tipe data `int` dan menyimpannya pada variabel `umur_2023`.
# 4. Program meminta informasi kepemilikan **SIM C** dengan pilihan `y/t`. Karakter pertama dari input diambil, kemudian diubah menjadi huruf kecil dan disimpan pada `sim_c_2023`.
# 5. Program menampilkan lima pilihan paket wahana beserta harga masing-masing.
# 6. Pengguna memilih nomor paket wahana dan memasukkan **jumlah tiket** yang ingin dibeli.
# 7. Program memeriksa jumlah tiket. Jika jumlah tiket kurang dari atau sama dengan 0, program menampilkan **"Jumlah tiket tidak valid!"** dan menghentikan program.
# 8. Jika jumlah tiket valid, program meminta status **member** dan **kode promo** dari pengguna.
# 9. Program menggunakan struktur **`match-case`** untuk menentukan paket wahana yang dipilih sekaligus melakukan pemeriksaan kelayakan berdasarkan umur dan SIM.
# 10. Pada **Safari Rimba**, program memeriksa apakah umur pengunjung minimal 10 tahun. Jika memenuhi, pengunjung diperbolehkan menggunakan wahana sendiri. Jika tidak, pengunjung wajib didampingi orang tua. Harga tiket ditetapkan sebesar **Rp50.000**.
# 11. Pada **Arung Jeram**, program memeriksa apakah umur pengunjung minimal 15 tahun. Jika memenuhi, pengunjung diperbolehkan menggunakan wahana sendiri. Jika tidak, pengunjung wajib didampingi orang tua. Harga tiket ditetapkan sebesar **Rp75.000**.
# 12. Pada **Motor ATV Ekstrim**, program memeriksa umur dan kepemilikan SIM C menggunakan kondisi `if`, `elif`, dan `else`. Pengunjung berusia minimal 17 tahun dan memiliki SIM C diperbolehkan mengendarai ATV sendiri. Harga tiket ditetapkan sebesar **Rp120.000**.
# 13. Pada **Roller Coaster Kilat**, program memeriksa apakah umur pengunjung minimal 17 tahun. Jika memenuhi, pengunjung diperbolehkan menggunakan wahana sendiri. Jika tidak, pengunjung wajib didampingi orang tua. Harga tiket ditetapkan sebesar **Rp100.000**.
# 14. Pada **All-Access VIP**, program memeriksa umur dan kepemilikan SIM C. Jika berusia minimal 17 tahun dan memiliki SIM C, pengunjung diperbolehkan menggunakan semua wahana sendiri. Jika tidak memenuhi persyaratan, program memberikan keterangan sesuai kondisi yang diperiksa. Harga tiket ditetapkan sebesar **Rp220.000**.
# 15. Jika nomor paket yang dimasukkan tidak sesuai dengan pilihan 1–5, program menampilkan **"Paket wahana tidak valid!"** dan menghentikan program.
# 16. Program menetapkan nilai awal `diskon_2023` sebesar **0%**.
# 17. Program memeriksa apakah total harga tiket minimal **Rp200.000**. Jika terpenuhi, diskon ditambahkan sebesar **10%**.
# 18. Program memeriksa status member. Jika input berupa `y` atau `ya`, diskon ditambahkan sebesar **5%**.
# 19. Program memeriksa kode promo. Jika input berupa `y` atau `ya`, diskon ditambahkan sebesar **15%**.
# 20. Program memeriksa jumlah tiket. Jika jumlah tiket minimal **5**, diskon ditambahkan sebesar **5%**.
# 21. Karena menggunakan beberapa `if` secara terpisah, setiap diskon dapat **diakumulasikan** apabila beberapa kondisi terpenuhi.
# 22. Program menghitung **subtotal belanja** dengan mengalikan harga satuan tiket dengan jumlah tiket.
# 23. Program menghitung **nominal diskon** berdasarkan persentase diskon yang telah diperoleh.
# 24. Program menghitung **total pembayaran** dengan mengurangi subtotal belanja dengan nominal diskon.
# 25. Program menampilkan rincian pembayaran berupa subtotal belanja, total diskon, dan total pembayaran.
# 26. Program memeriksa apakah subtotal belanja lebih dari **Rp300.000**. Jika terpenuhi, program menampilkan informasi bahwa pengunjung mendapatkan **souvenir gratis**.
# 27. Program menampilkan catatan layanan berupa ucapan terima kasih kepada pengunjung.
# 28. Program menampilkan pesan **"Program Selesai"** dan program berakhir.
#
# </div>

# %% [markdown]
# ---
# <div style="height:1123px;font-family: 'Times New Roman', Times, serif;font-size: 18px;">
# <h1 align="center">BAB III<br>KESIMPULAN</h1>
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa conditional merupakan salah satu konsep penting dalam pemrograman Python yang digunakan untuk menentukan perintah berdasarkan kondisi tertentu. Conditional dapat dibuat menggunakan if, elif, dan else, serta dapat dikombinasikan dengan operator perbandingan maupun operator logika.
#
# Dengan memahami conditional, mahasiswa dapat membuat program yang mampu mengambil keputusan dan menghasilkan keluaran yang berbeda sesuai dengan kondisi yang diberikan. Pemahaman ini menjadi dasar penting untuk membuat program Python yang lebih interaktif dan sesuai dengan kebutuhan.
# </div>

# %% [markdown]
# ---
# <div style="height:1123px;font-family: 'Times New Roman', Times, serif;font-size: 18px;">
# <h1 align="center">DAFTAR PUSTAKA</h1>
#
# 1. Python Software Foundation. (2026). *The Python Tutorial: More Control Flow Tools*. Python.org. https://docs.python.org/3/tutorial/controlflow.html
#
# 2. Python Software Foundation. (2026). *Python 3 Documentation*. Python.org. https://docs.python.org/3/
#
# 3. W3Schools. (2026). *Python Conditions*. W3Schools. https://www.w3schools.com/python/python_conditions.asp
#
# 4. GeeksforGeeks. (2026). *Python if-else*. GeeksforGeeks. https://www.geeksforgeeks.org/python/python-if-else/
#
# </div>
